# %% [markdown]
# # Ex. No: 09
# #  Record-IMPLEMENTATION OF EROSION AND DILATION
#
# ### **Name:** Sanjay C    **Reg. No:** 212223240150

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
def load_img():
    img = np.zeros((600, 600), dtype='uint8')   
    font = cv2.FONT_HERSHEY_SIMPLEX             
    cv2.putText(img, 'SANJAY', (150, 300), font, 2, (255), 5, cv2.LINE_AA)
    return img

# %%
def display_img(img):
    plt.title("Image")
    plt.imshow(img)
    plt.axis('off')
    plt.show()

# %%
img = load_img()
display_img(img)
kernel = np.ones((6, 7), np.uint8)

# %%
eroded_image = cv2.erode(img, kernel, iterations=1)
plt.imshow(cv2.cvtColor(eroded_image, cv2.COLOR_BGR2RGB)) 
plt.title("Eroded Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(599.5), np.float64(599.5), np.float64(-0.5))

# %%
dilated_image = cv2.dilate(img, kernel, iterations=1)
plt.imshow(cv2.cvtColor(dilated_image, cv2.COLOR_BGR2RGB))
plt.title("Dilated Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(599.5), np.float64(599.5), np.float64(-0.5))
